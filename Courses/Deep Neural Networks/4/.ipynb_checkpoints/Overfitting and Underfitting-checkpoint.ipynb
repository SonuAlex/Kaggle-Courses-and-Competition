# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks

# %%
spotify = pd.read_csv('spotify.csv')

#Dividing the data
X = spotify.copy().dropna()
y = X.pop('track_popularity')
artists = X['track_artist']

#Making 2 feature lists
features_num = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 
                'liveness', 'valence', 'tempo', 'duration_ms']
features_cat = ['playlist_genre']

#Preprocessing
preprocessor = make_column_transformer(
    (StandardScaler(), features_num),
    (OneHotEncoder(), features_cat)
)


def group_split(X, y, group, train_size=0.75):
    splitter = GroupShuffleSplit(train_size=train_size)
    train, test = next(splitter.split(X, y, groups=group))
    return (X.iloc[train], X.iloc[test], y.iloc[train], y.iloc[test])

#Splitting train and test data
X_train, X_valid, y_train, y_valid = group_split(X, y, artists)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
y_train = y_train / 100      #Since popularity is from 0-100 we rescale it 0-1
y_valid = y_valid / 100

input_shape = [X_train.shape[1]]
print("Input shape = ", input_shape)
# Out:
# Input shape =  [18]

# %%
#Making a simple network, a linear model.
model = keras.Sequential([
    layers.Dense(1, input_shape=input_shape)
])
model.compile(
    optimizer='adam',
    loss='mae'
)
history = model.fit(
    X_train, y_train,
    validation_data = (X_valid, y_valid),
    batch_size = 512,
    epochs = 50,
    verbose = 0    #Supress the output so we can plot the graph
)
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()))
# Out:
# Minimum Validation Loss: 0.2001

# %%
history_df.loc[12:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Minimum Validation Loss: 0.2001

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mae'
)

history = model.fit(
    X_train, y_train,
    validation_data = (X_valid, y_valid),
    batch_size = 512,
    epochs = 50
)
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss = {:0.4f}".format(history_df['val_loss'].min()))
# Out:
# Epoch 1/50
# 48/48 [==============================] - 1s 5ms/step - loss: 0.2517 - val_loss: 0.2105
# Epoch 2/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.2009 - val_loss: 0.2053
# Epoch 3/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1952 - val_loss: 0.2029
# Epoch 4/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1925 - val_loss: 0.2026
# Epoch 5/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1903 - val_loss: 0.2016
# Epoch 6/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1883 - val_loss: 0.2014
# Epoch 7/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1877 - val_loss: 0.2004
# Epoch 8/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1860 - val_loss: 0.2004
# Epoch 9/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1852 - val_loss: 0.1998
# Epoch 10/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1842 - val_loss: 0.2015
# Epoch 11/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1832 - val_loss: 0.1989
# Epoch 12/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1830 - val_loss: 0.2009
# Epoch 13/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1821 - val_loss: 0.2016
# Epoch 14/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1814 - val_loss: 0.2019
# Epoch 15/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1809 - val_loss: 0.2009
# Epoch 16/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1799 - val_loss: 0.2010
# Epoch 17/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1802 - val_loss: 0.2006
# Epoch 18/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1792 - val_loss: 0.2021
# Epoch 19/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1789 - val_loss: 0.2007
# Epoch 20/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1782 - val_loss: 0.2016
# Epoch 21/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1777 - val_loss: 0.2017
# Epoch 22/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1771 - val_loss: 0.2034
# Epoch 23/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1766 - val_loss: 0.2024
# Epoch 24/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1760 - val_loss: 0.2024
# Epoch 25/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1750 - val_loss: 0.2016
# Epoch 26/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1749 - val_loss: 0.2015
# Epoch 27/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1745 - val_loss: 0.2017
# Epoch 28/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1737 - val_loss: 0.2022
# Epoch 29/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1734 - val_loss: 0.2039
# Epoch 30/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1728 - val_loss: 0.2024
# Epoch 31/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1740 - val_loss: 0.2027
# Epoch 32/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1719 - val_loss: 0.2038
# Epoch 33/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1713 - val_loss: 0.2027
# Epoch 34/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1712 - val_loss: 0.2031
# Epoch 35/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1706 - val_loss: 0.2044
# Epoch 36/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1697 - val_loss: 0.2035
# Epoch 37/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1699 - val_loss: 0.2032
# Epoch 38/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1693 - val_loss: 0.2042
# Epoch 39/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1692 - val_loss: 0.2050
# Epoch 40/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1687 - val_loss: 0.2051
# Epoch 41/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1685 - val_loss: 0.2054
# Epoch 42/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1686 - val_loss: 0.2085
# Epoch 43/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1675 - val_loss: 0.2046
# Epoch 44/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1670 - val_loss: 0.2047
# Epoch 45/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1661 - val_loss: 0.2069
# Epoch 46/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1664 - val_loss: 0.2057
# Epoch 47/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1652 - val_loss: 0.2081
# Epoch 48/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1648 - val_loss: 0.2054
# Epoch 49/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1655 - val_loss: 0.2056
# Epoch 50/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1649 - val_loss: 0.2069
# Minimum Validation Loss = 0.1989
