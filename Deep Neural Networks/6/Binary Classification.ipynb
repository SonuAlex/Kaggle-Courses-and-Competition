# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

# %%
hotel = pd.read_csv('hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February':2, 'March':3, 'April':4,
         'May':5, 'June':6, 'July':7, 'August':8, 'September':9,
         'October':10, 'November':11, 'December':12}
    )
    
features_num = ['lead_time', 'arrival_date_week_number', 'arrival_date_day_of_month',
              'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest',
               'previous_cancellations', 'previous_bookings_not_canceled', 'required_car_parking_spaces',
               'total_of_special_requests', 'adr',
              ]
features_cat = ['hotel', 'arrival_date_month', 'meal', 'market_segment',
               'distribution_channel', 'reserved_room_type',
               'deposit_type', 'customer_type',]

transformer_num = make_pipeline(
    SimpleImputer(strategy='constant'),
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy='constant', fill_value='NA'),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]
print("Input sHAPE = ", input_shape)
# Out:
# Input sHAPE =  [63]

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    
    layers.Dense(1, activation='sigmoid'),
])

# %%
model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['binary_accuracy'],
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience = 5,
    min_delta = 0.001,
    restore_best_weights = True
)

history = model.fit(
    X_train, y_train,
    validation_data = (X_valid, y_valid),
    batch_size = 512,
    epochs = 200,
    callbacks = [early_stopping]
)

history_df = pd.DataFrame(history.history)

history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-enthropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title='Accuracy')
# Out:
# Epoch 1/200
# 175/175 [==============================] - 4s 10ms/step - loss: 0.4866 - binary_accuracy: 0.7688 - val_loss: 0.4227 - val_binary_accuracy: 0.8112
# Epoch 2/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.4253 - binary_accuracy: 0.8013 - val_loss: 0.3985 - val_binary_accuracy: 0.8199
# Epoch 3/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.4121 - binary_accuracy: 0.8064 - val_loss: 0.3888 - val_binary_accuracy: 0.8202
# Epoch 4/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.4050 - binary_accuracy: 0.8102 - val_loss: 0.3853 - val_binary_accuracy: 0.8194
# Epoch 5/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.4001 - binary_accuracy: 0.8139 - val_loss: 0.3800 - val_binary_accuracy: 0.8244
# Epoch 6/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3956 - binary_accuracy: 0.8164 - val_loss: 0.3787 - val_binary_accuracy: 0.8270
# Epoch 7/200
# 175/175 [==============================] - 1s 9ms/step - loss: 0.3921 - binary_accuracy: 0.8181 - val_loss: 0.3722 - val_binary_accuracy: 0.8282
# Epoch 8/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3892 - binary_accuracy: 0.8190 - val_loss: 0.3750 - val_binary_accuracy: 0.8289
# Epoch 9/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3861 - binary_accuracy: 0.8209 - val_loss: 0.3713 - val_binary_accuracy: 0.8284
# Epoch 10/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3847 - binary_accuracy: 0.8221 - val_loss: 0.3674 - val_binary_accuracy: 0.8326
# Epoch 11/200
# 175/175 [==============================] - 1s 9ms/step - loss: 0.3809 - binary_accuracy: 0.8246 - val_loss: 0.3651 - val_binary_accuracy: 0.8337
# Epoch 12/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3772 - binary_accuracy: 0.8260 - val_loss: 0.3656 - val_binary_accuracy: 0.8320
# Epoch 13/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3757 - binary_accuracy: 0.8265 - val_loss: 0.3653 - val_binary_accuracy: 0.8321
# Epoch 14/200
# 175/175 [==============================] - 1s 9ms/step - loss: 0.3736 - binary_accuracy: 0.8272 - val_loss: 0.3616 - val_binary_accuracy: 0.8341
# Epoch 15/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3713 - binary_accuracy: 0.8293 - val_loss: 0.3578 - val_binary_accuracy: 0.8375
# Epoch 16/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3702 - binary_accuracy: 0.8296 - val_loss: 0.3534 - val_binary_accuracy: 0.8369
# Epoch 17/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3685 - binary_accuracy: 0.8297 - val_loss: 0.3549 - val_binary_accuracy: 0.8376
# Epoch 18/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3673 - binary_accuracy: 0.8300 - val_loss: 0.3577 - val_binary_accuracy: 0.8348
# Epoch 19/200
# 175/175 [==============================] - 1s 9ms/step - loss: 0.3658 - binary_accuracy: 0.8304 - val_loss: 0.3513 - val_binary_accuracy: 0.8379
# Epoch 20/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3636 - binary_accuracy: 0.8318 - val_loss: 0.3563 - val_binary_accuracy: 0.8365
# Epoch 21/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3623 - binary_accuracy: 0.8316 - val_loss: 0.3516 - val_binary_accuracy: 0.8381
# Epoch 22/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3603 - binary_accuracy: 0.8340 - val_loss: 0.3505 - val_binary_accuracy: 0.8386
# Epoch 23/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3596 - binary_accuracy: 0.8337 - val_loss: 0.3523 - val_binary_accuracy: 0.8365
# Epoch 24/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3605 - binary_accuracy: 0.8341 - val_loss: 0.3496 - val_binary_accuracy: 0.8400
# Epoch 25/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3569 - binary_accuracy: 0.8349 - val_loss: 0.3492 - val_binary_accuracy: 0.8396
# Epoch 26/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3559 - binary_accuracy: 0.8359 - val_loss: 0.3508 - val_binary_accuracy: 0.8393
# Epoch 27/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3550 - binary_accuracy: 0.8357 - val_loss: 0.3439 - val_binary_accuracy: 0.8407
# Epoch 28/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3537 - binary_accuracy: 0.8372 - val_loss: 0.3444 - val_binary_accuracy: 0.8408
# Epoch 29/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3534 - binary_accuracy: 0.8377 - val_loss: 0.3474 - val_binary_accuracy: 0.8393
# Epoch 30/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3520 - binary_accuracy: 0.8377 - val_loss: 0.3444 - val_binary_accuracy: 0.8419
# Epoch 31/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3509 - binary_accuracy: 0.8378 - val_loss: 0.3459 - val_binary_accuracy: 0.8394
# Epoch 32/200
# 175/175 [==============================] - 1s 9ms/step - loss: 0.3503 - binary_accuracy: 0.8389 - val_loss: 0.3429 - val_binary_accuracy: 0.8432
# <AxesSubplot: title={'center': 'Accuracy'}>
